# %%
import pandas as pd

# %%
# !pip install faker
# Out:
# Requirement already satisfied: faker in c:\users\nw user\appdata\local\programs\python\python311\lib\site-packages (24.11.0)
# Requirement already satisfied: python-dateutil>=2.4 in c:\users\nw user\appdata\local\programs\python\python311\lib\site-packages (from faker) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\nw user\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.4->faker) (1.16.0)

# %%
from faker import Faker
fake = Faker()

# %%
lista = []

# %%
for x in range(0,10000):
    lista.append({'nombre': fake.name(), 'last_name': fake.last_name(), 'email': fake.email(), 'address': fake.address()})

# %%
lista
# Out:
# [{'nombre': 'Nicholas Whitney',
#   'last_name': 'Peterson',
#   'email': 'jay10@example.net',
#   'address': '3043 Nicole Spur\nNorth Angelaland, NC 88693'},
#  {'nombre': 'Eric Gallagher',
#   'last_name': 'Alvarez',
#   'email': 'vgonzalez@example.org',
#   'address': '376 Jacqueline Coves\nNorth Sarah, NH 34867'},
#  {'nombre': 'Jeremy Ware',
#   'last_name': 'Brown',
#   'email': 'stanleycarroll@example.org',
#   'address': '5278 Simpson Forks\nNorth Thomasburgh, NY 48842'},
#  {'nombre': 'Omar Price',
#   'last_name': 'Knox',
#   'email': 'deborah17@example.com',
#   'address': '311 Montoya Mills Apt. 799\nSouth Jenna, DC 84325'},
#  {'nombre': 'Justin Patel',
#   'last_name': 'Powell',
#   'email': 'adam77@example.net',
#   'address': '48759 Edwards Pines\nLake Kimberly, MD 44577'},
#  {'nombre': 'Dr. Kathryn Perez PhD',
#   'last_name': 'Robinson',
#   'email': 'poncejennifer@example.net',
#   'address': 'Unit 7082 Box 9255\nDPO AP 19940'},
#  {'nombre': 'Mr. Thomas Lowe',
#   'last_name': 'Wilkinson',
#   'email': 'marysanders@example.net',
#   'address': '4777 Keith Extensions\nPort Lauraborough, DC 54894'},
#  {'nombre': 'Peter Marshall',
#   'last_name': 'Hunter',
#   'email': 'walkerjohn@example.com',
#   'address': 'USNV Flores\nFPO AA 42874'},
#  {'nombre': 'Steven Manning',
#   'last_name': 'Reed',
#   'email': 'michaeloliver@example.com',
#   'address': '0081 Melissa Burg\nErikahaven, MN 26742'},
#  {'nombre': 'Anthony Martinez',
#   'last_name': 'Fitzgerald',
#   'email': 'nstevens@example.org',
#   'address': '35244 Griffin Pine\nLloydchester, PW 85081'},
#  {'nombre': 'Elizabeth Anderson',
#   'last_name': 'Barker',
#   'email': 'michelle45@example.net',
#   'address': '636 Williams Hill\nMichealland, MN 00668'},
#  {'nombre': 'Sarah Bridges',
#   'last_name': 'Cunningham',
#   'email': 'jennifergrimes@example.com',
#   'address': '82658 Brandy Road\nEstesshire, WI 90163'},
#  {'nombre': 'Mary Lee',
#   'last_name': 'Wong',
#   'email': 'vpatrick@example.net',
#   'address': '58902 Madeline Mills\nNorth Aaron, FM 99750'},
#  {'nombre': 'John Robinson',
#   'last_name': 'Lambert',
#   'email': 'rebecca54@example.net',
#   'address': '3725 Massey Ville Suite 356\nNewmanhaven, PA 25470'},
#  {'nombre': 'Kimberly Odonnell',
#   'last_name': 'Perry',
#   'email': 'dhernandez@example.com',
#   'address': '2461 Jackson Valley Suite 458\nMartinchester, OK 10131'},
#  {'nombre': 'William Richard',
#   'last_name': 'Wilson',
#   'email': 'xramirez@example.org',
#   'address': '430 Troy Club Apt. 252\nJosephstad, VT 75093'},
#  {'nombre': 'Tonya Martin',
#   'last_name': 'Klein',
#   'email': 'barbaraparker@example.net',
#   'address': '4177 Williams Prairie\nDavidberg, AK 86282'},
#  {'nombre': 'Angelica Allen',
#   'last_name': 'Lewis',
#   'email': 'allendeanna@example.net',
#   'address': '474 Martinez Knoll\nSouth Shannonbury, RI 80789'},
#  {'nombre': 'Brian Leblanc',
#   'last_name': 'Smith',
#   'email': 'charles29@example.org',
#   'address': 'Unit 5643 Box 7096\nDPO AP 80484'},
#  {'nombre': 'Diana Kelley',
#   'last_name': 'Holmes',
#   'email': 'daviseric@example.com',
#   'address': '692 Tricia Fields Suite 953\nNorth Jacob, AL 70637'},
#  {'nombre': 'Donald Hall',
#   'last_name': 'Meyer',
#   'email': 'pcollins@example.net',
#   'address': '8311 Baxter Courts Apt. 080\nNorth John, SD 74422'},
#  {'nombre': 'Sherry Cook',
#   'last_name': 'Patterson',
#   'email': 'lindsaygill@example.org',
#   'address': '32511 Susan Villages Suite 746\nLisaville, MP 07407'},
#  {'nombre': 'Laura Meza',
#   'last_name': 'Smith',
#   'email': 'dlewis@example.org',
#   'address': '728 Maria Islands\nEast Jameston, TX 48314'},
#  {'nombre': 'Christina Johnson',
#   'last_name': 'Mullins',
#   'email': 'jacksonkevin@example.net',
#   'address': '2440 Dean Alley\nNew Jessica, CO 51040'},
#  {'nombre': 'Stephanie Gray',
#   'last_name': 'Holloway',
#   'email': 'washingtoncynthia@example.org',
#   'address': '683 Brandy Neck\nEast Samantha, UT 00902'},
#  {'nombre': 'Marissa Williams',
#   'last_name': 'Blanchard',
#   'email': 'garciacraig@example.com',
#   'address': '28145 Wu Ville Apt. 217\nNew Kristin, MD 67263'},
#  {'nombre': 'Cindy Powell',
#   'last_name': 'Boyer',
#   'email': 'anthony82@example.org',
#   'address': '975 Mary Rue Suite 664\nGreenhaven, WY 12374'},
#  {'nombre': 'Robert Ray',
#   'last_name': 'Calhoun',
#   'email': 'crobertson@example.com',
#   'address': '556 Ashley Port Suite 780\nNorth Thomas, WV 28416'},
#  {'nombre': 'Brittany Torres',
#   'last_name': 'Greene',
#   'email': 'robertbrown@example.org',
#   'address': '336 Vargas Harbors\nWest Mariaside, MO 78243'},
#  {'nombre': 'Thomas Munoz',
#   'last_name': 'Clark',
#   'email': 'wellstimothy@example.net',
#   'address': '9417 Jones Viaduct\nPort Garyfurt, SD 17684'},
#  {'nombre': 'Lawrence Clark',
#   'last_name': 'Harris',
#   'email': 'hannahleach@example.org',
#   'address': '7131 White Mission\nLake Jennifer, HI 78901'},
#  {'nombre': 'Kristine Rose',
#   'last_name': 'Miller',
#   'email': 'danielarellano@example.org',
#   'address': '145 Pacheco Ways Suite 554\nRachelland, VA 95280'},
#  {'nombre': 'Lisa Harmon',
#   'last_name': 'Villa',
#   'email': 'roachemily@example.net',
#   'address': '72359 Vazquez Dam Apt. 622\nNew Lancefort, PW 65871'},
#  {'nombre': 'Gina Mullen',
#   'last_name': 'Miller',
#   'email': 'ispears@example.org',
#   'address': '182 Maria Pike Apt. 459\nShanemouth, IA 19251'},
#  {'nombre': 'Michael Harris',
#   'last_name': 'Kemp',
#   'email': 'ywells@example.org',
#   'address': '206 Rebecca Bridge Suite 873\nEast Caitlinberg, NE 90404'},
#  {'nombre': 'Allen Martinez',
#   'last_name': 'Stewart',
#   'email': 'davenportrichard@example.org',
#   'address': '004 Gill Row Apt. 131\nLake Russell, NJ 68420'},
#  {'nombre': 'Kevin Jenkins',
#   'last_name': 'Wood',
#   'email': 'joel60@example.org',
#   'address': '406 White Stravenue Suite 806\nNew Jessicaborough, OH 57290'},
#  {'nombre': 'Danny Schmidt',
#   'last_name': 'Mcdonald',
#   'email': 'eric99@example.net',
#   'address': '02222 James Center\nEast Debbie, MP 67310'},
#  {'nombre': 'Tyler Munoz',
#   'last_name': 'Valdez',
#   'email': 'tammy98@example.org',
#   'address': 'PSC 8838, Box 0768\nAPO AA 99274'},
#  {'nombre': 'Bryan Palmer',
#   'last_name': 'Mason',
#   'email': 'martinsarah@example.org',
#   'address': '36838 Parker Street Suite 372\nWest Zachary, NJ 49572'},
#  {'nombre': 'Scott Guzman',
#   'last_name': 'Clay',
#   'email': 'grantwright@example.net',
#   'address': '057 Frey Station Apt. 414\nMelanieville, NC 91202'},
#  {'nombre': 'Joanna Wilson',
#   'last_name': 'Blackburn',
#   'email': 'jbenton@example.net',
#   'address': '860 Omar Radial\nLaurabury, GA 34875'},
#  {'nombre': 'Brenda Lee',
#   'last_name': 'Johnston',
#   'email': 'darin82@example.org',
#   'address': '6468 Vasquez Harbors Suite 251\nMarkhaven, IN 91146'},
#  {'nombre': 'Zoe Allen',
#   'last_name': 'Harris',
#   'email': 'jacobwaller@example.com',
#   'address': '02507 Richard Groves\nScottbury, SD 17758'},
#  {'nombre': 'Stacy Moss',
#   'last_name': 'Gregory',
#   'email': 'nicholas64@example.com',
#   'address': '936 Justin Coves Suite 336\nLake Christopher, MP 57155'},
#  {'nombre': 'Pamela Montgomery',
#   'last_name': 'Pope',
#   'email': 'shall@example.com',
#   'address': '15170 Mary Radial\nDonnaborough, HI 29719'},
#  {'nombre': 'Thomas Martin',
#   'last_name': 'Tucker',
#   'email': 'carneyjonathan@example.com',
#   'address': 'Unit 6547 Box 4239\nDPO AP 24916'},
#  {'nombre': 'Denise Smith',
#   'last_name': 'Murray',
#   'email': 'thompsonkathleen@example.com',
#   'address': '279 Perez Plains\nLake Ericland, MH 07035'},
#  {'nombre': 'Thomas Peters',
#   'last_name': 'Wright',
#   'email': 'natalieosborn@example.net',
#   'address': '9363 Hansen Court Apt. 610\nNorth Kyleton, MT 32747'},
#  {'nombre': 'Erik West',
#   'last_name': 'Vargas',
#   'email': 'tiffanyharvey@example.org',
#   'address': '635 Meghan Meadows Apt. 118\nSouth Nathan, WI 83795'},
#  {'nombre': 'Adam Johnson',
#   'last_name': 'Mcknight',
#   'email': 'tbrown@example.com',
#   'address': '4802 Christina Well Apt. 777\nNguyenfurt, OR 23268'},
#  {'nombre': 'Bethany Sanchez',
#   'last_name': 'Davis',
#   'email': 'vdodson@example.net',
#   'address': '6165 Graves Motorway Suite 104\nPort Heatherport, NY 80664'},
#  {'nombre': 'Amy Hines',
#   'last_name': 'Ortiz',
#   'email': 'gjohnson@example.org',
#   'address': '868 Cox Place\nNew Taylorview, OK 22857'},
#  {'nombre': 'Brittney Newman',
#   'last_name': 'Ramirez',
#   'email': 'angelabonilla@example.com',
#   'address': '8495 Connie Estate Suite 008\nNorth Rachelville, OR 53789'},
#  {'nombre': 'Mark Kim',
#   'last_name': 'Cole',
#   'email': 'laurajohnson@example.net',
#   'address': 'PSC 3549, Box 1254\nAPO AP 97851'},
#  {'nombre': 'Cory Taylor',
#   'last_name': 'Wiley',
#   'email': 'hillkatrina@example.com',
#   'address': '38500 Kelly Forest Apt. 940\nSmithshire, NE 97426'},
#  {'nombre': 'Heather Lester',
#   'last_name': 'Graves',
#   'email': 'derek24@example.org',
#   'address': '57045 Stephanie Parkway\nSouth David, DE 47619'},
#  {'nombre': 'Eric Hines',
#   'last_name': 'Baker',
#   'email': 'mcdowellerika@example.net',
#   'address': 'PSC 6678, Box 3108\nAPO AE 24440'},
#  {'nombre': 'Wendy Lin',
#   'last_name': 'Harris',
#   'email': 'mcneildustin@example.org',
#   'address': '331 Johnson Village Apt. 248\nWest Sheri, VA 19303'},
#  {'nombre': 'Nicole Campbell',
#   'last_name': 'Alvarez',
#   'email': 'andrewsmith@example.com',
#   'address': '59684 Jacob Walks Suite 335\nWest Kimberly, NE 87934'},
#  {'nombre': 'Tammy Lynch',
#   'last_name': 'Moore',
#   'email': 'jonesthomas@example.org',
#   'address': '991 Veronica Key\nNorth Felicia, GA 49255'},
#  {'nombre': 'Sonya Collins',
#   'last_name': 'Odonnell',
#   'email': 'cadams@example.net',
#   'address': '34339 Matthew Walks Suite 194\nLake Lisa, VA 93593'},
#  {'nombre': 'Meghan Torres',
#   'last_name': 'Kemp',
#   'email': 'michellearcher@example.org',
#   'address': '6601 Alexander Mountains\nNathanfort, IN 70885'},
#  {'nombre': 'Daniel Harrison',
#   'last_name': 'Anderson',
#   'email': 'moonashley@example.org',
#   'address': '357 Richard Terrace\nLindaside, VA 10217'},
#  {'nombre': 'Sara Lawrence',
#   'last_name': 'Hayes',
#   'email': 'riggskevin@example.net',
#   'address': '4998 Heather Vista\nNew Samuelton, IL 17439'},
#  {'nombre': 'Christopher Smith',
#   'last_name': 'Jones',
#   'email': 'melissa64@example.com',
#   'address': '066 Dana Center\nWest Alejandraside, MP 19080'},
#  {'nombre': 'Deanna Miller',
#   'last_name': 'Brown',
#   'email': 'michael82@example.org',
#   'address': '868 Desiree Expressway Apt. 176\nRobertsonberg, PA 36282'},
#  {'nombre': 'James Contreras',
#   'last_name': 'Yoder',
#   'email': 'veronicamorales@example.com',
#   'address': '73895 Patterson Plains Suite 451\nTonyborough, DC 44722'},
#  {'nombre': 'Scott Williams',
#   'last_name': 'Roman',
#   'email': 'jmichael@example.org',
#   'address': '9485 Benitez Expressway Apt. 676\nNorth Michael, MS 83318'},
#  {'nombre': 'Joshua Frey',
#   'last_name': 'Gutierrez',
#   'email': 'zsmith@example.org',
#   'address': '1279 Mark Coves Apt. 120\nNorth Kenneth, WY 07670'},
#  {'nombre': 'Pam Bryan',
#   'last_name': 'Santos',
#   'email': 'ruthcampbell@example.com',
#   'address': '2377 Guerrero Circles Apt. 871\nSouth Brianna, MD 45176'},
#  {'nombre': 'Kathryn Klein',
#   'last_name': 'Norton',
#   'email': 'jason72@example.net',
#   'address': '2431 Rivera Common Suite 810\nVancestad, MN 45585'},
#  {'nombre': 'Angela Burgess',
#   'last_name': 'Smith',
#   'email': 'alexis52@example.net',
#   'address': '6460 Nicole Causeway Suite 670\nWest Jamieborough, MP 92629'},
#  {'nombre': 'Jose Lopez',
#   'last_name': 'White',
#   'email': 'adrienne33@example.org',
#   'address': '186 Matthew Pike\nAndretown, WV 54111'},
#  {'nombre': 'Erika Harrison',
#   'last_name': 'Horton',
#   'email': 'michaelcisneros@example.org',
#   'address': 'Unit 8515 Box 3004\nDPO AA 09036'},
#  {'nombre': 'Robert Mcdonald',
#   'last_name': 'Glass',
#   'email': 'samuelhendricks@example.com',
#   'address': '0705 Peter Meadows Suite 198\nDavidburgh, OR 39267'},
#  {'nombre': 'Lindsey Frazier',
#   'last_name': 'Woods',
#   'email': 'jenniferharrison@example.org',
#   'address': '27674 Young Locks Suite 947\nLeemouth, AZ 06566'},
#  {'nombre': 'Robert Gill',
#   'last_name': 'Butler',
#   'email': 'vincentadam@example.net',
#   'address': '36454 Allen Terrace\nEast David, WY 19737'},
#  {'nombre': 'Tom Kelly',
#   'last_name': 'Meadows',
#   'email': 'richardsanchez@example.org',
#   'address': 'USNS Gallagher\nFPO AE 68943'},
#  {'nombre': 'Joanna Hood',
#   'last_name': 'Pena',
#   'email': 'jonesmadison@example.net',
#   'address': '322 Jennifer Squares Apt. 927\nNew Darryl, NC 10572'},
#  {'nombre': 'James Nixon',
#   'last_name': 'Mcclain',
#   'email': 'psmith@example.com',
#   'address': '82885 Rodriguez Curve\nArmstrongtown, TN 59256'},
#  {'nombre': 'Darren Richardson',
#   'last_name': 'Daniels',
#   'email': 'erinwalker@example.org',
#   'address': '4962 Allen Isle Apt. 148\nReedshire, LA 16740'},
#  {'nombre': 'Elizabeth Jordan',
#   'last_name': 'Thomas',
#   'email': 'taylorlaura@example.net',
#   'address': '5496 Scott Port Suite 971\nWest Samuelfort, IL 11675'},
#  {'nombre': 'Donald Taylor',
#   'last_name': 'Frank',
#   'email': 'jefferyreynolds@example.net',
#   'address': '07803 Freeman Groves Apt. 381\nPort Kimberlyton, WY 14672'},
#  {'nombre': 'Curtis Wood',
#   'last_name': 'Moreno',
#   'email': 'deborahhammond@example.com',
#   'address': '103 Rogers Rapids Suite 682\nWest Joseph, VA 22964'},
#  {'nombre': 'Derek Perez',
#   'last_name': 'Bird',
#   'email': 'kfigueroa@example.com',
#   'address': '06951 Bryan Light Apt. 673\nAmandaberg, PA 27214'},
#  {'nombre': 'Bernard Miller',
#   'last_name': 'Patel',
#   'email': 'egonzalez@example.net',
#   'address': '673 Palmer Gateway Apt. 910\nSouth Amandamouth, NE 10683'},
#  {'nombre': 'Colin Horton',
#   'last_name': 'Sanchez',
#   'email': 'erica04@example.com',
#   'address': 'Unit 6763 Box 6459\nDPO AA 72964'},
#  {'nombre': 'Logan Mathis',
#   'last_name': 'Hughes',
#   'email': 'rodgerserica@example.com',
#   'address': '40430 Christopher Drive\nEast Megan, AR 25391'},
#  {'nombre': 'Adam Brooks',
#   'last_name': 'Ward',
#   'email': 'bailey88@example.org',
#   'address': '47980 Doris Burgs Suite 618\nJulieberg, IA 43433'},
#  {'nombre': 'Scott Taylor',
#   'last_name': 'Reid',
#   'email': 'ruizjennifer@example.com',
#   'address': '1149 William Island Apt. 971\nPort Georgeville, DC 74335'},
#  {'nombre': 'Alexander Pugh',
#   'last_name': 'Moyer',
#   'email': 'brewerjason@example.com',
#   'address': '9285 Chelsea Springs Apt. 584\nEast Danielfurt, PW 22656'},
#  {'nombre': 'Sharon Wong',
#   'last_name': 'Yates',
#   'email': 'obailey@example.org',
#   'address': '6728 Mckinney Falls\nStaceyburgh, DC 07855'},
#  {'nombre': 'Robert Lynch',
#   'last_name': 'Kerr',
#   'email': 'cunninghamlaura@example.org',
#   'address': '02852 Eric Village Apt. 974\nMarquezland, DE 45737'},
#  {'nombre': 'Katrina Harper',
#   'last_name': 'Hanson',
#   'email': 'williamwoods@example.com',
#   'address': '560 Aaron Squares Apt. 367\nGamblefort, SC 86012'},
#  {'nombre': 'Mark Miller',
#   'last_name': 'Taylor',
#   'email': 'xcampbell@example.net',
#   'address': '347 Rebecca Cliffs\nWest Shellyfort, TN 80275'},
#  {'nombre': 'Ryan Williams',
#   'last_name': 'Marshall',
#   'email': 'kwilliams@example.org',
#   'address': '4259 Robinson Street Apt. 111\nSouth Seanshire, NH 20315'},
#  {'nombre': 'Amanda Bell',
#   'last_name': 'Walker',
#   'email': 'elizabethprice@example.org',
#   'address': '44336 Hensley Motorway\nGwendolynberg, IL 99128'},
#  {'nombre': 'Kayla Nelson',
#   'last_name': 'Rivera',
#   'email': 'kcarpenter@example.net',
#   'address': '6181 Megan Bypass\nEast Deannaport, VT 04206'},
#  {'nombre': 'Jennifer Perez',
#   'last_name': 'Garcia',
#   'email': 'michele79@example.com',
#   'address': '634 Woods Corners\nSouth Davidfurt, HI 23345'},
#  {'nombre': 'Jill Hughes',
#   'last_name': 'Butler',
#   'email': 'thomas38@example.net',
#   'address': '152 Douglas Spring Suite 878\nNew Melissamouth, AL 78267'},
#  {'nombre': 'Brooke Parker',
#   'last_name': 'Thomas',
#   'email': 'pateldarren@example.org',
#   'address': 'PSC 7749, Box 0447\nAPO AE 07884'},
#  {'nombre': 'Steven Graves',
#   'last_name': 'Murphy',
#   'email': 'nicholsbrett@example.net',
#   'address': '516 Erica Road\nWest Angelatown, FM 48192'},
#  {'nombre': 'Amber Herman',
#   'last_name': 'Fernandez',
#   'email': 'brianna85@example.org',
#   'address': '226 Hogan Park Suite 960\nGloriabury, HI 16465'},
#  {'nombre': 'Deborah Roberson',
#   'last_name': 'Johnson',
#   'email': 'tiffany59@example.org',
#   'address': '283 Lee Knolls\nPort Codymouth, ND 73624'},
#  {'nombre': 'Rebecca Figueroa',
#   'last_name': 'Patrick',
#   'email': 'hayden04@example.org',
#   'address': 'PSC 3079, Box 2856\nAPO AE 87316'},
#  {'nombre': 'Monica Davis',
#   'last_name': 'Jacobs',
#   'email': 'shelly26@example.com',
#   'address': '80585 Samantha Row\nPort Felicia, OR 22521'},
#  {'nombre': 'Austin Pace',
#   'last_name': 'Hill',
#   'email': 'bellroger@example.net',
#   'address': '343 Acosta Loaf Apt. 019\nLake Kelly, MD 93429'},
#  {'nombre': 'Ellen Smith',
#   'last_name': 'Johnson',
#   'email': 'jasminelogan@example.net',
#   'address': '34331 Daniel Mount\nJustinview, NY 59843'},
#  {'nombre': 'Jeremy Nguyen',
#   'last_name': 'Anderson',
#   'email': 'wendyday@example.net',
#   'address': '129 Karen Vista Suite 036\nNew Brianna, VA 87002'},
#  {'nombre': 'Brian Todd',
#   'last_name': 'Powers',
#   'email': 'claygeorge@example.net',
#   'address': '07594 Lisa Parkway Apt. 552\nLake Elizabethside, RI 88596'},
#  {'nombre': 'Adrian Arellano',
#   'last_name': 'Cox',
#   'email': 'danapowell@example.com',
#   'address': '301 Davis Corners\nNew Timothy, NY 27922'},
#  {'nombre': 'Lauren Pham',
#   'last_name': 'Montoya',
#   'email': 'teresa94@example.org',
#   'address': '926 Carrie Isle\nNorth Joshuaside, ND 02593'},
#  {'nombre': 'Matthew Wong',
#   'last_name': 'Walker',
#   'email': 'brenda73@example.com',
#   'address': '6163 Tina Port Apt. 120\nSouth Brandifurt, OR 47088'},
#  {'nombre': 'Joyce Patrick',
#   'last_name': 'Callahan',
#   'email': 'rachelabbott@example.com',
#   'address': '41568 Hall Isle Suite 407\nChristopherhaven, AZ 23339'},
#  {'nombre': 'Austin Pope',
#   'last_name': 'Shaffer',
#   'email': 'morenochristina@example.com',
#   'address': '291 Donald Forge\nJosehaven, UT 43608'},
#  {'nombre': 'Colleen Hart',
#   'last_name': 'Lane',
#   'email': 'bbell@example.org',
#   'address': '2921 Jessica Roads Apt. 767\nEast Andrew, NY 51781'},
#  {'nombre': 'Robert Thompson',
#   'last_name': 'Williams',
#   'email': 'ysmith@example.com',
#   'address': '1159 Campbell Extensions\nBarberstad, OR 08248'},
#  {'nombre': 'Gina Rivas',
#   'last_name': 'Garner',
#   'email': 'meganavery@example.net',
#   'address': '3527 Vicki Dam\nNew Robert, WA 30935'},
#  {'nombre': 'Patrick Mcintyre',
#   'last_name': 'Santos',
#   'email': 'emilydean@example.org',
#   'address': '0240 Jasmine Extensions\nContrerasmouth, OR 38124'},
#  {'nombre': 'David Wells',
#   'last_name': 'Sharp',
#   'email': 'lauren89@example.org',
#   'address': '682 Michelle Spurs\nLaurenville, NC 45386'},
#  {'nombre': 'Shawn Hunter',
#   'last_name': 'Sanders',
#   'email': 'fletcherdavid@example.com',
#   'address': '492 Brewer Village Apt. 117\nEast Jessicaton, MI 77030'},
#  {'nombre': 'Joseph Reyes',
#   'last_name': 'Fox',
#   'email': 'jennifer34@example.net',
#   'address': '150 Kelly Garden\nRichardstad, NH 28503'},
#  {'nombre': 'Tyler Williams',
#   'last_name': 'Ferguson',
#   'email': 'stephanieford@example.org',
#   'address': '4693 Johnson Ford Suite 707\nDominicmouth, MI 23804'},
#  {'nombre': 'Timothy Johnson',
#   'last_name': 'Juarez',
#   'email': 'tracy71@example.net',
#   'address': '61917 Johnson Pass Apt. 815\nBarronport, PW 70355'},
#  {'nombre': 'Melissa Lozano',
#   'last_name': 'Wright',
#   'email': 'brian57@example.org',
#   'address': '91460 Michele Mall\nJohnsonview, NY 16773'},
#  {'nombre': 'William Perry',
#   'last_name': 'Miller',
#   'email': 'emilycabrera@example.com',
#   'address': '86435 Calvin Island\nSouth Jenniferside, TN 13523'},
#  {'nombre': 'Eric Ward',
#   'last_name': 'Williams',
#   'email': 'melaniefox@example.net',
#   'address': '298 Jackson Hill\nNew Ashley, WA 62529'},
#  {'nombre': 'Tyler Nunez',
#   'last_name': 'Roberts',
#   'email': 'laurie21@example.net',
#   'address': '40392 Albert Green\nEast Jasminestad, ND 13465'},
#  {'nombre': 'Joseph Morris',
#   'last_name': 'Hawkins',
#   'email': 'laura05@example.org',
#   'address': '28983 Brewer Drives Suite 694\nPort Nathan, UT 01439'},
#  {'nombre': 'Katherine Phillips',
#   'last_name': 'Acosta',
#   'email': 'brandonbaldwin@example.com',
#   'address': '9486 Robert Meadow\nAndersonchester, IL 18693'},
#  {'nombre': 'Christian Briggs',
#   'last_name': 'Underwood',
#   'email': 'ljohnson@example.org',
#   'address': '766 Elizabeth Groves Apt. 080\nSouth Steven, IL 20506'},
#  {'nombre': 'John Durham',
#   'last_name': 'Graves',
#   'email': 'pgraves@example.net',
#   'address': '017 Mercedes Ways\nPort Gabriela, CA 46287'},
#  {'nombre': 'Christina Flores',
#   'last_name': 'Kennedy',
#   'email': 'htaylor@example.org',
#   'address': '91005 Brian Groves\nThomasbury, FL 94193'},
#  {'nombre': 'Sandra Reeves',
#   'last_name': 'Faulkner',
#   'email': 'andersonmadeline@example.com',
#   'address': '800 Amanda Brook\nSouth Josehaven, AR 31820'},
#  {'nombre': 'Gary Fisher',
#   'last_name': 'Williams',
#   'email': 'andrew72@example.org',
#   'address': '9751 Cody Freeway Apt. 761\nLake Sarahshire, ME 58096'},
#  {'nombre': 'Lisa Escobar',
#   'last_name': 'Pollard',
#   'email': 'kimsteven@example.net',
#   'address': '22054 Scott Curve\nGomezberg, TX 44737'},
#  {'nombre': 'Peter Massey',
#   'last_name': 'Walker',
#   'email': 'davischristine@example.net',
#   'address': '40418 Kenneth Crossing Suite 784\nEast Clayton, NH 28468'},
#  {'nombre': 'Emily Knight',
#   'last_name': 'Phillips',
#   'email': 'hendersonwilliam@example.org',
#   'address': '61553 Victoria Mills Suite 877\nDarrylmouth, KY 17709'},
#  {'nombre': 'Phillip Hanson',
#   'last_name': 'Brown',
#   'email': 'qmorrison@example.org',
#   'address': '46922 Donna Ford Suite 173\nNorth Brittanyhaven, NM 73847'},
#  {'nombre': 'Lisa Jarvis',
#   'last_name': 'Austin',
#   'email': 'williamsanthony@example.org',
#   'address': '838 Myers Point\nLake Brianmouth, MN 63529'},
#  {'nombre': 'Amanda White',
#   'last_name': 'Garcia',
#   'email': 'theresa07@example.com',
#   'address': '13031 Anita Crest\nEast Williamstad, FL 93394'},
#  {'nombre': 'Gregory Torres',
#   'last_name': 'Cardenas',
#   'email': 'knightjennifer@example.org',
#   'address': 'USNS Smith\nFPO AP 25771'},
#  {'nombre': 'Eric Valenzuela',
#   'last_name': 'Caldwell',
#   'email': 'jameswhite@example.org',
#   'address': 'PSC 6874, Box 4691\nAPO AE 54698'},
#  {'nombre': 'Lori Pineda',
#   'last_name': 'Fisher',
#   'email': 'khanaaron@example.org',
#   'address': '58574 April Points Suite 056\nEast Christopherfort, IN 23145'},
#  {'nombre': 'Paul Brown',
#   'last_name': 'Frazier',
#   'email': 'lindseyflores@example.net',
#   'address': '715 Reed Road Suite 963\nPort Alexis, TN 15846'},
#  {'nombre': 'Kevin Wright',
#   'last_name': 'Nelson',
#   'email': 'john64@example.org',
#   'address': '0131 John Valleys Apt. 840\nEricatown, NJ 27550'},
#  {'nombre': 'Frederick Copeland',
#   'last_name': 'Day',
#   'email': 'richardcraig@example.com',
#   'address': '40584 Joseph Streets\nLake Lisamouth, HI 01813'},
#  {'nombre': 'Kimberly Wells',
#   'last_name': 'Kennedy',
#   'email': 'webertodd@example.net',
#   'address': '30195 Robert Route Suite 763\nRobertbury, AZ 60038'},
#  {'nombre': 'Kelly Alvarez',
#   'last_name': 'Woods',
#   'email': 'mary52@example.org',
#   'address': '8463 Williams Light\nNorth Martin, NE 43943'},
#  {'nombre': 'George Walker',
#   'last_name': 'Brown',
#   'email': 'andreobrien@example.org',
#   'address': '86158 Gary Fields Suite 491\nEast Jessica, MI 38619'},
#  {'nombre': 'Laura Nichols',
#   'last_name': 'George',
#   'email': 'nnelson@example.org',
#   'address': 'PSC 2603, Box 4163\nAPO AE 33447'},
#  {'nombre': 'Teresa Jensen',
#   'last_name': 'Ellis',
#   'email': 'cooperzachary@example.com',
#   'address': '45506 Green Parks Suite 922\nSchwartzmouth, DC 32906'},
#  {'nombre': 'Amy Maldonado',
#   'last_name': 'Shah',
#   'email': 'chanpatrick@example.org',
#   'address': '81544 Francis Shoal\nRogerstown, MP 19083'},
#  {'nombre': 'Hector Garrett',
#   'last_name': 'Sanchez',
#   'email': 'daviscorey@example.net',
#   'address': '8702 Peter Street Suite 868\nSouth Sabrinafort, CO 75267'},
#  {'nombre': 'Jacqueline Garcia',
#   'last_name': 'Young',
#   'email': 'dianarogers@example.org',
#   'address': '728 Ashley Roads Apt. 881\nWilliamsland, DC 75138'},
#  {'nombre': 'Ellen Ruiz',
#   'last_name': 'Taylor',
#   'email': 'kimberlyjohnson@example.org',
#   'address': '4767 Pruitt Road\nShawfort, MT 76334'},
#  {'nombre': 'Theresa Leon',
#   'last_name': 'Ortega',
#   'email': 'hernandezscott@example.com',
#   'address': '64285 Robert Pass\nMichaelfort, RI 06715'},
#  {'nombre': 'Daniel Young',
#   'last_name': 'Hardy',
#   'email': 'heather93@example.org',
#   'address': '42656 Marshall Summit Apt. 977\nDonaldsonborough, PR 01621'},
#  {'nombre': 'Sara Russo',
#   'last_name': 'Mullins',
#   'email': 'scottking@example.org',
#   'address': 'USS Harris\nFPO AP 57856'},
#  {'nombre': 'Tina Hood',
#   'last_name': 'Torres',
#   'email': 'johnsonvalerie@example.org',
#   'address': '621 David Estate Suite 764\nKimburgh, WY 75977'},
#  {'nombre': 'Timothy Tran',
#   'last_name': 'Whitehead',
#   'email': 'charles13@example.org',
#   'address': '040 Nguyen View Suite 433\nLake Natalieborough, NM 82016'},
#  {'nombre': 'Janice Eaton',
#   'last_name': 'Jimenez',
#   'email': 'brittany40@example.com',
#   'address': '7522 Mike Rapids\nBrandonborough, MD 34910'},
#  {'nombre': 'Rachael Jenkins',
#   'last_name': 'Hernandez',
#   'email': 'phowell@example.org',
#   'address': '7740 Christopher Oval\nPort Tina, VI 34070'},
#  {'nombre': 'Stephanie Taylor',
#   'last_name': 'Solis',
#   'email': 'martinkeith@example.net',
#   'address': '753 Murray Ports\nLake Brandyshire, TN 86576'},
#  {'nombre': 'Daniel Knapp',
#   'last_name': 'Strong',
#   'email': 'drobinson@example.com',
#   'address': '5266 Timothy Islands\nSouth James, HI 53765'},
#  {'nombre': 'Dennis Krueger',
#   'last_name': 'Reeves',
#   'email': 'samantha10@example.net',
#   'address': '77413 Smith Cliff\nNew Carl, NY 87932'},
#  {'nombre': 'Sandra Knight',
#   'last_name': 'Chung',
#   'email': 'david16@example.org',
#   'address': '549 Anthony Pines Apt. 288\nPerezshire, RI 12745'},
#  {'nombre': 'Richard Benitez',
#   'last_name': 'Reed',
#   'email': 'kent28@example.com',
#   'address': '466 Lawson Pass\nMackenziefort, NY 83436'},
#  {'nombre': 'Jerry Moreno',
#   'last_name': 'Perkins',
#   'email': 'brian28@example.org',
#   'address': '251 Kennedy Cove Suite 532\nLake Dwayne, MH 00584'},
#  {'nombre': 'Janet Duncan',
#   'last_name': 'Ramirez',
#   'email': 'uvasquez@example.net',
#   'address': '276 Ashley Mills Apt. 850\nSouth Richardport, NV 24863'},
#  {'nombre': 'Brent Collins',
#   'last_name': 'Davis',
#   'email': 'elizabethmurray@example.net',
#   'address': '8452 Hernandez Oval\nSouth Thomasfurt, WV 86461'},
#  {'nombre': 'Lisa Aguilar',
#   'last_name': 'Morgan',
#   'email': 'marco74@example.net',
#   'address': '48629 Winters Falls Suite 615\nSouth Jason, AL 49618'},
#  {'nombre': 'Victoria Dorsey',
#   'last_name': 'Nelson',
#   'email': 'grojas@example.com',
#   'address': '108 Huber Fords\nNew Jared, MA 62784'},
#  {'nombre': 'Maria Foster',
#   'last_name': 'Garcia',
#   'email': 'sarahgallagher@example.com',
#   'address': '0739 Deanna Club\nLarryfurt, MP 59763'},
#  {'nombre': 'Kevin Avila',
#   'last_name': 'Martin',
#   'email': 'aprilmartinez@example.net',
#   'address': '18321 Teresa Alley\nNew Kristenberg, NH 65964'},
#  {'nombre': 'George Cook',
#   'last_name': 'Murphy',
#   'email': 'oliververonica@example.com',
#   'address': '06321 Kathryn Views\nNorth Troystad, PR 55683'},
#  {'nombre': 'Ann Frazier',
#   'last_name': 'Ortiz',
#   'email': 'carlbailey@example.org',
#   'address': '2855 Kelsey Mills\nLake Ashley, TN 07983'},
#  {'nombre': 'William Carter',
#   'last_name': 'Shaffer',
#   'email': 'elliottisabella@example.net',
#   'address': '015 Walker Manors\nSanchezchester, PR 62319'},
#  {'nombre': 'Robert Allen',
#   'last_name': 'Smith',
#   'email': 'criley@example.org',
#   'address': 'PSC 9950, Box 3484\nAPO AE 87815'},
#  {'nombre': 'Angela Cannon',
#   'last_name': 'Garcia',
#   'email': 'elizabethchan@example.com',
#   'address': '05518 Lin Squares Suite 735\nTranfurt, CO 65792'},
#  {'nombre': 'Robert Suarez Jr.',
#   'last_name': 'Baker',
#   'email': 'nowens@example.org',
#   'address': '40587 Michael Stream\nMarciaborough, PW 84107'},
#  {'nombre': 'Gloria Garcia',
#   'last_name': 'Khan',
#   'email': 'chase52@example.org',
#   'address': '85478 Cindy Meadow Suite 078\nWest Kevinview, NE 34192'},
#  {'nombre': 'Joe Acosta',
#   'last_name': 'Peters',
#   'email': 'bakerthomas@example.net',
#   'address': '7368 Kimberly Views Suite 312\nRamosstad, OR 22435'},
#  {'nombre': 'Sandra Hernandez',
#   'last_name': 'Olsen',
#   'email': 'jeffreymurray@example.net',
#   'address': '496 Hale Gardens Suite 578\nCortezberg, OR 17255'},
#  {'nombre': 'Michael Brown',
#   'last_name': 'Bailey',
#   'email': 'nicholasnguyen@example.net',
#   'address': 'PSC 8128, Box 5892\nAPO AA 27938'},
#  {'nombre': 'Adam Barajas',
#   'last_name': 'Fox',
#   'email': 'greenesarah@example.net',
#   'address': '7100 Joshua Groves\nZacharyberg, AZ 05365'},
#  {'nombre': 'Christina Garcia',
#   'last_name': 'Humphrey',
#   'email': 'bmurphy@example.com',
#   'address': '037 Jordan Summit Suite 242\nSouth Nathaniel, WY 20398'},
#  {'nombre': 'Rose Carter',
#   'last_name': 'Turner',
#   'email': 'hjohnson@example.com',
#   'address': 'PSC 6729, Box 5981\nAPO AE 05508'},
#  {'nombre': 'Andrew Mccoy',
#   'last_name': 'Johnson',
#   'email': 'arroyowilliam@example.net',
#   'address': '943 Braun Union\nPort Robertside, NC 55572'},
#  {'nombre': 'Roy Cole',
#   'last_name': 'Tucker',
#   'email': 'donald41@example.net',
#   'address': '99546 King Overpass Apt. 198\nLake Tarastad, SC 95990'},
#  {'nombre': 'Anita Alvarez',
#   'last_name': 'Moore',
#   'email': 'barberkevin@example.org',
#   'address': '09704 Kellie Skyway\nMitchellton, GU 00520'},
#  {'nombre': 'Katherine Ramirez',
#   'last_name': 'Little',
#   'email': 'regina58@example.net',
#   'address': 'PSC 5873, Box 4799\nAPO AA 65732'},
#  {'nombre': 'Jerry Cantu',
#   'last_name': 'Woodard',
#   'email': 'xjones@example.com',
#   'address': '931 Rowe Villages\nCrossport, NH 03497'},
#  {'nombre': 'James Francis',
#   'last_name': 'Hernandez',
#   'email': 'millsmelissa@example.com',
#   'address': '95772 Bell Junctions\nLake Aprilhaven, IN 88679'},
#  {'nombre': 'Nancy Walker',
#   'last_name': 'Powell',
#   'email': 'tylerfrye@example.com',
#   'address': '67582 Page Groves Suite 537\nAnthonychester, NY 69200'},
#  {'nombre': 'Rebecca Davis',
#   'last_name': 'York',
#   'email': 'kingjerry@example.net',
#   'address': '484 Mark Lakes Apt. 388\nWest Gregory, CO 93270'},
#  {'nombre': 'Timothy Harrison',
#   'last_name': 'Oconnor',
#   'email': 'kirbysusan@example.org',
#   'address': '29375 Dwayne Fords\nByrdburgh, CO 71336'},
#  {'nombre': 'Patrick Lynch',
#   'last_name': 'Burgess',
#   'email': 'stephen77@example.net',
#   'address': '4398 Cheyenne Drives\nEllisonchester, WA 64861'},
#  {'nombre': 'Jacob Lewis',
#   'last_name': 'Sanchez',
#   'email': 'staceyhoward@example.com',
#   'address': '68618 Bush Inlet\nDanielstad, GU 30339'},
#  {'nombre': 'Patrick Watson',
#   'last_name': 'Walker',
#   'email': 'williamsmark@example.net',
#   'address': '457 Donald Stravenue\nLake Charles, LA 78284'},
#  {'nombre': 'Isaac Wilson',
#   'last_name': 'Reed',
#   'email': 'danderson@example.net',
#   'address': '16550 Miller Hill\nRobertside, NY 47586'},
#  {'nombre': 'Kimberly Reed',
#   'last_name': 'Greene',
#   'email': 'julia95@example.org',
#   'address': '915 James Wall Apt. 436\nLewisburgh, LA 40935'},
#  {'nombre': 'Aaron Romero',
#   'last_name': 'Villanueva',
#   'email': 'wardmichael@example.org',
#   'address': 'PSC 1354, Box 7219\nAPO AA 26318'},
#  {'nombre': 'Erik Williams',
#   'last_name': 'Thomas',
#   'email': 'bbrown@example.com',
#   'address': '02780 Jeffery Trace\nNorth Heatherberg, MI 05919'},
#  {'nombre': 'Cory Cooper',
#   'last_name': 'Williams',
#   'email': 'tarahooper@example.net',
#   'address': '762 Jermaine Port Suite 618\nPort Hunterport, IN 53643'},
#  {'nombre': 'Pamela Wang',
#   'last_name': 'Allen',
#   'email': 'harold74@example.com',
#   'address': '25728 Brittany Rest\nChristopherville, WV 79943'},
#  {'nombre': 'David Carr',
#   'last_name': 'Snyder',
#   'email': 'fstone@example.net',
#   'address': '31899 Wolfe Cliffs\nCodymouth, AR 73123'},
#  {'nombre': 'Natasha Chapman',
#   'last_name': 'Hoffman',
#   'email': 'kellyarnold@example.com',
#   'address': '0117 Steven Branch Suite 658\nJustinstad, WI 49524'},
#  {'nombre': 'Kim Jones',
#   'last_name': 'Green',
#   'email': 'tammy33@example.com',
#   'address': '6326 Matthew Mills\nMartinezborough, MN 88012'},
#  {'nombre': 'James Mullins',
#   'last_name': 'Morales',
#   'email': 'turnerjacob@example.com',
#   'address': '0018 Robert Stravenue Apt. 884\nWest Brian, VI 85325'},
#  {'nombre': 'Sara Hernandez',
#   'last_name': 'Cook',
#   'email': 'melissa69@example.net',
#   'address': '748 Tyler Walk Apt. 439\nGracefurt, NC 68087'},
#  {'nombre': 'David Cruz',
#   'last_name': 'Weber',
#   'email': 'riveravictoria@example.com',
#   'address': '2895 Tiffany Glen Apt. 283\nLake Jessica, MA 63196'},
#  {'nombre': 'Thomas Ward',
#   'last_name': 'Castro',
#   'email': 'eoneill@example.org',
#   'address': '39532 Andrew Isle Apt. 506\nWest Patricia, WV 54290'},
#  {'nombre': 'Sandra Burnett',
#   'last_name': 'Lewis',
#   'email': 'rachelhenry@example.org',
#   'address': '9334 Miles Street Suite 979\nNorth Wendy, PA 63243'},
#  {'nombre': 'Robert Jones',
#   'last_name': 'White',
#   'email': 'dawn80@example.net',
#   'address': '2773 Mann Estates\nSouth Brandon, VI 23894'},
#  {'nombre': 'Teresa Harvey',
#   'last_name': 'Solomon',
#   'email': 'george58@example.com',
#   'address': 'USNS Harper\nFPO AP 24764'},
#  {'nombre': 'Cindy Valentine',
#   'last_name': 'Clark',
#   'email': 'tdunn@example.net',
#   'address': '5809 Ashley Harbors Suite 992\nNew Karen, AK 33638'},
#  {'nombre': 'Jennifer Nixon MD',
#   'last_name': 'Stone',
#   'email': 'tiffany26@example.net',
#   'address': '3118 Daugherty Court Apt. 544\nMoodytown, MP 27781'},
#  {'nombre': 'Darlene Gardner',
#   'last_name': 'Johnson',
#   'email': 'maria95@example.net',
#   'address': '641 Torres Ports Suite 482\nWest Jacob, KY 17347'},
#  {'nombre': 'Richard Hopkins',
#   'last_name': 'Miller',
#   'email': 'coryflores@example.net',
#   'address': '47716 Joel Rest Suite 819\nEast Andrew, MP 47551'},
#  {'nombre': 'Cynthia Harris',
#   'last_name': 'Allen',
#   'email': 'pricenancy@example.org',
#   'address': 'Unit 8036 Box 8907\nDPO AP 95749'},
#  {'nombre': 'Regina Delgado',
#   'last_name': 'Silva',
#   'email': 'hayesrobert@example.com',
#   'address': '423 Alvarez Union\nNorth Darrellfurt, NJ 79007'},
#  {'nombre': 'Cynthia Moore',
#   'last_name': 'Lee',
#   'email': 'zacharysmith@example.org',
#   'address': '428 Dustin Rapid\nThorntonfurt, SD 40971'},
#  {'nombre': 'Deborah Eaton',
#   'last_name': 'Pierce',
#   'email': 'nancyross@example.net',
#   'address': '025 Kelly Mountain Suite 324\nLake Harry, MD 72438'},
#  {'nombre': 'Jennifer Wagner',
#   'last_name': 'Pratt',
#   'email': 'halvarez@example.net',
#   'address': '485 Miller Trafficway\nRoseborough, TN 31220'},
#  {'nombre': 'Donna Boyle',
#   'last_name': 'Wu',
#   'email': 'larry61@example.org',
#   'address': '888 Briana Junction Suite 912\nFlynnport, NH 78161'},
#  {'nombre': 'Jerry Butler',
#   'last_name': 'Johnson',
#   'email': 'mitchellevans@example.net',
#   'address': '83412 Lindsey Unions\nSouth Seanton, AR 85659'},
#  {'nombre': 'Christopher Clark',
#   'last_name': 'Hart',
#   'email': 'ronaldallen@example.org',
#   'address': '9500 Brown Village\nRobertport, UT 05766'},
#  {'nombre': 'Andrea Wallace',
#   'last_name': 'Smith',
#   'email': 'lynchcassandra@example.com',
#   'address': '4329 Frazier Mews Suite 641\nNew Kristina, HI 09603'},
#  {'nombre': 'Christopher Estrada',
#   'last_name': 'Salinas',
#   'email': 'michellelee@example.net',
#   'address': '90938 Julia Point Suite 851\nLake Leah, DE 72041'},
#  {'nombre': 'Kenneth Edwards',
#   'last_name': 'Ramirez',
#   'email': 'russellwanda@example.org',
#   'address': '628 Hill Courts\nNew Robertstad, AZ 57200'},
#  {'nombre': 'John Lee',
#   'last_name': 'Green',
#   'email': 'kdalton@example.com',
#   'address': '1744 Shannon Run\nBryantfurt, IN 17781'},
#  {'nombre': 'Mary Ayers',
#   'last_name': 'Harris',
#   'email': 'barrettheather@example.org',
#   'address': '463 Cline Port\nTranburgh, VA 78988'},
#  {'nombre': 'Brittany Rodriguez',
#   'last_name': 'Brown',
#   'email': 'srice@example.org',
#   'address': 'Unit 6392 Box 7958\nDPO AE 44587'},
#  {'nombre': 'Gabrielle Young',
#   'last_name': 'Griffith',
#   'email': 'joy43@example.net',
#   'address': '52292 Martinez Shoal Suite 106\nJessicatown, IN 30693'},
#  {'nombre': 'Cindy Drake',
#   'last_name': 'Mcconnell',
#   'email': 'lewisjared@example.net',
#   'address': '398 Amber Ferry Apt. 644\nJohnmouth, SC 23022'},
#  {'nombre': 'Ashley Christian',
#   'last_name': 'Turner',
#   'email': 'lutzjoshua@example.com',
#   'address': '3501 Tran Spurs Suite 034\nLake Christopherton, ND 88475'},
#  {'nombre': 'Robert Thompson',
#   'last_name': 'Vang',
#   'email': 'blackburnjeremy@example.org',
#   'address': '9256 Susan Lights\nRichardstad, KS 89093'},
#  {'nombre': 'Dana Kelly',
#   'last_name': 'Mills',
#   'email': 'dawn56@example.net',
#   'address': 'PSC 3391, Box 2972\nAPO AA 40890'},
#  {'nombre': 'Fernando Phelps',
#   'last_name': 'Hawkins',
#   'email': 'kpayne@example.org',
#   'address': '340 Jennifer Spring\nJordanborough, RI 36128'},
#  {'nombre': 'Sierra Christensen',
#   'last_name': 'Wilcox',
#   'email': 'tarawilkins@example.com',
#   'address': '0849 Paula Lake Apt. 065\nCastillohaven, AK 40640'},
#  {'nombre': 'Margaret Lewis',
#   'last_name': 'Rojas',
#   'email': 'shelby95@example.com',
#   'address': '02829 Lewis Wells Suite 395\nZacharyland, KS 30359'},
#  {'nombre': 'Anna Mccullough',
#   'last_name': 'White',
#   'email': 'hendrickscody@example.net',
#   'address': '91572 Jonathan Motorway Suite 391\nLake Ericview, TX 24759'},
#  {'nombre': 'Nicholas Rogers',
#   'last_name': 'Erickson',
#   'email': 'monique35@example.org',
#   'address': '893 Henry Neck\nKevinview, OH 41255'},
#  {'nombre': 'Melissa Crawford',
#   'last_name': 'Johnson',
#   'email': 'wellsgabriela@example.org',
#   'address': '4039 Grimes Falls\nLake Danny, TX 13487'},
#  {'nombre': 'Daniel Gentry',
#   'last_name': 'Hill',
#   'email': 'jasondyer@example.com',
#   'address': '91917 Waller Views\nNew Kennethton, KS 53384'},
#  {'nombre': 'Rita Gonzalez',
#   'last_name': 'Gomez',
#   'email': 'robinsonalison@example.com',
#   'address': '30942 Bates Village\nWest Jamiemouth, GU 35151'},
#  {'nombre': 'Tracy Trevino',
#   'last_name': 'Baker',
#   'email': 'jacqueline10@example.org',
#   'address': '02097 Deborah Glen Suite 225\nClarkhaven, MN 76497'},
#  {'nombre': 'Douglas Ramirez',
#   'last_name': 'Mahoney',
#   'email': 'lewisdiana@example.net',
#   'address': '15308 Price Cape\nSouth Jared, PW 93815'},
#  {'nombre': 'Alexander Green',
#   'last_name': 'Smith',
#   'email': 'garciafrank@example.com',
#   'address': '9328 Billy Place Suite 920\nJeanettemouth, MD 68485'},
#  {'nombre': 'Nicole Garza',
#   'last_name': 'Macdonald',
#   'email': 'denisemcgrath@example.com',
#   'address': '209 Suarez Stravenue Apt. 892\nLake Jamesshire, FL 36537'},
#  {'nombre': 'Melissa Miller',
#   'last_name': 'Mora',
#   'email': 'kathleenburton@example.org',
#   'address': 'USNV Smith\nFPO AE 92285'},
#  {'nombre': 'Nicole Flores',
#   'last_name': 'Vincent',
#   'email': 'ricebrandy@example.org',
#   'address': '18462 Torres Common\nNorth Timothy, SC 40570'},
#  {'nombre': 'Brian Harris',
#   'last_name': 'Jennings',
#   'email': 'christopherbrown@example.net',
#   'address': 'USNS Cole\nFPO AA 57482'},
#  {'nombre': 'Mary Berry',
#   'last_name': 'Knox',
#   'email': 'stephaniejackson@example.com',
#   'address': '3051 Christopher Spring\nNorth Julieland, ID 57631'},
#  {'nombre': 'Katrina Roberts',
#   'last_name': 'Marquez',
#   'email': 'halvarado@example.com',
#   'address': 'PSC 9798, Box 9573\nAPO AE 31695'},
#  {'nombre': 'Alicia Perry',
#   'last_name': 'George',
#   'email': 'petersennicole@example.com',
#   'address': 'USS Mitchell\nFPO AE 46029'},
#  {'nombre': 'Christopher Carter',
#   'last_name': 'Jones',
#   'email': 'ppowell@example.com',
#   'address': '89902 Ward Plaza\nHinesmouth, MO 25945'},
#  {'nombre': 'Melinda Levy',
#   'last_name': 'Smith',
#   'email': 'fortiz@example.org',
#   'address': '698 Jose Court Suite 157\nMollytown, GU 69367'},
#  {'nombre': 'Dustin Brown',
#   'last_name': 'Berger',
#   'email': 'christopher14@example.com',
#   'address': '69797 Lozano Plaza Apt. 795\nAdamsstad, PR 60057'},
#  {'nombre': 'Patrick Howard',
#   'last_name': 'Lee',
#   'email': 'rachelrichardson@example.com',
#   'address': 'USCGC Vasquez\nFPO AE 45962'},
#  {'nombre': 'Amy Kane',
#   'last_name': 'Bauer',
#   'email': 'rsteele@example.org',
#   'address': '6053 Thomas Glen\nMelissaborough, HI 21445'},
#  {'nombre': 'Ralph Kelly',
#   'last_name': 'Baker',
#   'email': 'anthony83@example.com',
#   'address': '87053 Jillian Landing Suite 616\nSouth Karen, NC 71403'},
#  {'nombre': 'Alicia Brown',
#   'last_name': 'Parks',
#   'email': 'yboyer@example.com',
#   'address': '462 Ruiz Meadow\nLeahton, ME 10484'},
#  {'nombre': 'Valerie Waters',
#   'last_name': 'Gray',
#   'email': 'nmann@example.net',
#   'address': '54162 Danielle Forges Suite 726\nMartinezside, KY 15781'},
#  {'nombre': 'Toni Harrell',
#   'last_name': 'Wallace',
#   'email': 'mark03@example.org',
#   'address': '2697 Moreno Bridge Suite 413\nGarretttown, AZ 34727'},
#  {'nombre': 'Sean Morales',
#   'last_name': 'Medina',
#   'email': 'williamsrobert@example.net',
#   'address': '950 Huff Circle\nEast Sandra, PA 06328'},
#  {'nombre': 'Ricky Stone',
#   'last_name': 'King',
#   'email': 'wshannon@example.com',
#   'address': '6689 Hart Mountains\nNew Charles, PR 41577'},
#  {'nombre': 'Theodore Gilmore',
#   'last_name': 'Liu',
#   'email': 'johnstondanielle@example.net',
#   'address': '31964 Holland Curve Suite 386\nLake Angela, WY 69305'},
#  {'nombre': 'James Atkins',
#   'last_name': 'Parker',
#   'email': 'raymondmelissa@example.com',
#   'address': '28042 Denise Camp\nDavidborough, TX 06780'},
#  {'nombre': 'Jason Guzman',
#   'last_name': 'Montgomery',
#   'email': 'wlittle@example.com',
#   'address': 'PSC 8761, Box 4158\nAPO AP 65492'},
#  {'nombre': 'Christine Morris',
#   'last_name': 'Fisher',
#   'email': 'saragonzalez@example.net',
#   'address': 'PSC 3308, Box 5378\nAPO AA 50143'},
#  {'nombre': 'Austin Davis',
#   'last_name': 'Chavez',
#   'email': 'rbowers@example.com',
#   'address': '94875 Jackson Road Apt. 107\nSouth Emily, KS 78160'},
#  {'nombre': 'Karen Sanford',
#   'last_name': 'Schmidt',
#   'email': 'elizabeth05@example.org',
#   'address': '927 Patton Turnpike Suite 054\nWest Donaldborough, MN 02475'},
#  {'nombre': 'Melissa Terry',
#   'last_name': 'Salinas',
#   'email': 'jesse71@example.org',
#   'address': '760 Edwards Lodge\nAguilarmouth, KY 44817'},
#  {'nombre': 'Christopher Campbell',
#   'last_name': 'Perkins',
#   'email': 'elizabethsmith@example.net',
#   'address': '7261 Murphy Valleys\nLindaside, KY 22911'},
#  {'nombre': 'Catherine Calderon',
#   'last_name': 'Fitzpatrick',
#   'email': 'perkinssara@example.org',
#   'address': '725 James Terrace Apt. 554\nNorth Sarah, NV 35544'},
#  {'nombre': 'David Cherry',
#   'last_name': 'Roberts',
#   'email': 'bradleyrich@example.com',
#   'address': '370 Ronald Flat Apt. 368\nHuntmouth, CO 67510'},
#  {'nombre': 'Nicole Avery',
#   'last_name': 'Drake',
#   'email': 'rlewis@example.net',
#   'address': '313 Eric Park Apt. 922\nArmstrongtown, PW 28383'},
#  {'nombre': 'Michelle Farley',
#   'last_name': 'Howe',
#   'email': 'ohooper@example.net',
#   'address': 'PSC 9113, Box 8630\nAPO AE 73236'},
#  {'nombre': 'Roberta Scott',
#   'last_name': 'Rodriguez',
#   'email': 'washingtonjuan@example.com',
#   'address': '999 Landry Highway\nBlakeport, TN 34461'},
#  {'nombre': 'Nancy Gomez',
#   'last_name': 'Morris',
#   'email': 'danielmoore@example.org',
#   'address': '5675 Joseph Gardens\nNew Christian, NV 22051'},
#  {'nombre': 'Gina Murray',
#   'last_name': 'Baker',
#   'email': 'christopherthomas@example.com',
#   'address': '69143 Jennifer Loaf Apt. 355\nPort Sherifort, NH 94247'},
#  {'nombre': 'Jesus Jackson',
#   'last_name': 'Higgins',
#   'email': 'rebecca46@example.net',
#   'address': '070 James Ranch Apt. 197\nDavidtown, CO 49588'},
#  {'nombre': 'Megan Allen',
#   'last_name': 'West',
#   'email': 'uthompson@example.com',
#   'address': '6826 Jennifer Bypass\nDavidshire, OK 04504'},
#  {'nombre': 'Nancy Daniels',
#   'last_name': 'Reynolds',
#   'email': 'caroline42@example.com',
#   'address': '9317 Melissa Landing Apt. 824\nSchmittfort, IL 37919'},
#  {'nombre': 'Stephanie Dunn',
#   'last_name': 'Barnes',
#   'email': 'rebecca27@example.com',
#   'address': '65217 Scott Throughway Suite 530\nNorth Sandra, VI 48820'},
#  {'nombre': 'Taylor Barton',
#   'last_name': 'Whitehead',
#   'email': 'ywilliams@example.net',
#   'address': '26689 Katelyn Fields Apt. 778\nNorth Aaron, DC 16852'},
#  {'nombre': 'Tyler Lowe',
#   'last_name': 'Bailey',
#   'email': 'ybaker@example.com',
#   'address': '77600 William Inlet Suite 542\nNew Laura, IA 17893'},
#  {'nombre': 'Monica Johns',
#   'last_name': 'Palmer',
#   'email': 'schang@example.com',
#   'address': '2063 Smith Canyon Apt. 960\nJacobsonmouth, CA 46725'},
#  {'nombre': 'Kayla Pacheco',
#   'last_name': 'Bennett',
#   'email': 'matthewmoore@example.com',
#   'address': '430 Zachary Springs Apt. 258\nWest Peter, IL 70827'},
#  {'nombre': 'Gregory Santos',
#   'last_name': 'Taylor',
#   'email': 'carrollpatrick@example.com',
#   'address': '599 Vickie Locks Apt. 624\nNorth Jerome, MH 64330'},
#  {'nombre': 'Taylor Clark',
#   'last_name': 'Jackson',
#   'email': 'dlara@example.com',
#   'address': '0139 Teresa Mall\nWest Jose, FM 67670'},
#  {'nombre': 'Jeffrey Craig',
#   'last_name': 'Stewart',
#   'email': 'rebeccanewton@example.org',
#   'address': '34456 Anderson Corners\nPort Sandrabury, CA 20576'},
#  {'nombre': 'Amber Ford',
#   'last_name': 'Mckee',
#   'email': 'andrea86@example.com',
#   'address': '181 Barnes Curve Suite 407\nNorth Zacharymouth, MA 23454'},
#  {'nombre': 'Stacey Solis',
#   'last_name': 'Sawyer',
#   'email': 'tara53@example.net',
#   'address': '06916 Mitchell Landing Suite 601\nJimmyland, AR 58310'},
#  {'nombre': 'Tammy Scott',
#   'last_name': 'Sexton',
#   'email': 'deborahschaefer@example.org',
#   'address': '64642 Sheila Roads\nHollyshire, NH 94565'},
#  {'nombre': 'Shelly Garcia',
#   'last_name': 'Johnson',
#   'email': 'jasonwells@example.com',
#   'address': '75445 Thomas Vista\nNorth Meganborough, NH 85752'},
#  {'nombre': 'Priscilla Jones',
#   'last_name': 'Blair',
#   'email': 'joshua44@example.org',
#   'address': 'USCGC Jones\nFPO AE 30387'},
#  {'nombre': 'Joshua Bruce',
#   'last_name': 'Johnson',
#   'email': 'alexandertravis@example.org',
#   'address': '7144 Jesus Cove Suite 039\nNorth Waynebury, CO 22923'},
#  {'nombre': 'Charles Smith',
#   'last_name': 'Dalton',
#   'email': 'madisonharris@example.net',
#   'address': '733 Kevin Path\nSouth Taylor, VA 15755'},
#  {'nombre': 'Joe Morris',
#   'last_name': 'Palmer',
#   'email': 'lauralandry@example.net',
#   'address': '506 Gregory Roads\nPort Marieberg, ID 79064'},
#  {'nombre': 'Julia Rogers',
#   'last_name': 'Arnold',
#   'email': 'christopher29@example.org',
#   'address': '318 Hill Alley Suite 420\nEast Davidchester, NM 04645'},
#  {'nombre': 'Kenneth Allen',
#   'last_name': 'Campbell',
#   'email': 'montgomerykathleen@example.net',
#   'address': '806 Sean Crossroad Apt. 832\nTimothyshire, MP 43970'},
#  {'nombre': 'Michael Rice',
#   'last_name': 'Barnes',
#   'email': 'darrelldavis@example.com',
#   'address': '83193 Kyle Cliff Suite 212\nNorth Elijahstad, NC 04920'},
#  {'nombre': 'Scott Jones',
#   'last_name': 'Davis',
#   'email': 'michaelcarter@example.net',
#   'address': '2106 Gina Trafficway Apt. 583\nMurraymouth, VT 82504'},
#  {'nombre': 'Chad Reynolds',
#   'last_name': 'Park',
#   'email': 'craig54@example.net',
#   'address': '123 Marilyn Estates\nAnnaborough, NJ 23369'},
#  {'nombre': 'Keith Davis',
#   'last_name': 'Caldwell',
#   'email': 'watkinsaustin@example.com',
#   'address': '22484 William Courts\nGutierrezside, AZ 81429'},
#  {'nombre': 'Michael Brown',
#   'last_name': 'White',
#   'email': 'pinedamatthew@example.org',
#   'address': '0173 Rose Forge\nShannonview, NY 82566'},
#  {'nombre': 'Cynthia Hunt',
#   'last_name': 'Cox',
#   'email': 'smithjohn@example.net',
#   'address': '0448 Tammy Lock Apt. 091\nRebeccaborough, FM 82748'},
#  {'nombre': 'Linda Newman',
#   'last_name': 'Bender',
#   'email': 'davidrodriguez@example.org',
# ...
#   'last_name': 'Graham',
#   'email': 'john39@example.com',
#   'address': '3774 Jones Streets\nSouth Jeffreyfort, SC 47015'},
#  {'nombre': 'Rhonda Chase',
#   'last_name': 'Stewart',
#   'email': 'andrewelliott@example.com',
#   'address': '3296 Bates Village Apt. 939\nTristanborough, HI 42118'},
#  {'nombre': 'Christine Allen',
#   'last_name': 'Mcgee',
#   'email': 'jacqueline38@example.net',
#   'address': '4136 Parsons River\nLake Calvin, FL 15205'},
#  {'nombre': 'John Foley',
#   'last_name': 'Johnson',
#   'email': 'garciakeith@example.com',
#   'address': '7605 Taylor Trail Apt. 007\nSouth Chris, AK 29260'},
#  {'nombre': 'Gina Mercado',
#   'last_name': 'Saunders',
#   'email': 'dbradley@example.net',
#   'address': '62402 Vang Fork Apt. 753\nSouth Lindsey, MN 96670'},
#  {'nombre': 'Robert Schaefer',
#   'last_name': 'Phillips',
#   'email': 'lcraig@example.com',
#   'address': 'PSC 6456, Box 4266\nAPO AP 90904'},
#  {'nombre': 'Brandon Larson',
#   'last_name': 'Roberts',
#   'email': 'irobinson@example.net',
#   'address': 'USNS Hernandez\nFPO AA 56166'},
#  {'nombre': 'Lisa Stone',
#   'last_name': 'Martinez',
#   'email': 'nicholas45@example.net',
#   'address': '3453 Erin Mountain Suite 791\nGutierrezmouth, NE 43090'},
#  {'nombre': 'Jordan Spence',
#   'last_name': 'Cruz',
#   'email': 'ssingh@example.org',
#   'address': '58822 Brett Turnpike\nJenniferberg, VA 21697'},
#  {'nombre': 'Christopher Hampton',
#   'last_name': 'Porter',
#   'email': 'christy90@example.com',
#   'address': 'USNV Morris\nFPO AE 01391'},
#  {'nombre': 'David Knox',
#   'last_name': 'Russell',
#   'email': 'joycejackson@example.net',
#   'address': '632 Murphy Prairie Suite 911\nAmandashire, ME 93628'},
#  {'nombre': 'Andrew Cummings',
#   'last_name': 'Watkins',
#   'email': 'schultzcrystal@example.com',
#   'address': '859 Latoya Union\nSouth Robertberg, NV 98615'},
#  {'nombre': 'Kevin Shaw',
#   'last_name': 'Rivera',
#   'email': 'stephen33@example.org',
#   'address': '9864 Jones Keys Suite 420\nShawnburgh, IL 97270'},
#  {'nombre': 'Robin Lara',
#   'last_name': 'Robertson',
#   'email': 'reginaodonnell@example.org',
#   'address': '69825 Lopez Ferry\nEast Matthewchester, ID 04489'},
#  {'nombre': 'Donald Johnson',
#   'last_name': 'Smith',
#   'email': 'andrew45@example.org',
#   'address': '6130 Sullivan Tunnel\nHollyshire, MS 97957'},
#  {'nombre': 'Kristopher Leon',
#   'last_name': 'Vance',
#   'email': 'johnsonkimberly@example.com',
#   'address': 'USCGC Wells\nFPO AP 41176'},
#  {'nombre': 'Philip Carter',
#   'last_name': 'Adams',
#   'email': 'christinachristensen@example.com',
#   'address': '612 Andrew Locks\nSouth Larry, WA 54426'},
#  {'nombre': 'Pamela Williams',
#   'last_name': 'Gomez',
#   'email': 'lhensley@example.org',
#   'address': '454 Miller Corner\nWest Rachel, MP 82444'},
#  {'nombre': 'Mary Perkins',
#   'last_name': 'Guzman',
#   'email': 'jadehunter@example.com',
#   'address': '2961 Bass Crossing Apt. 692\nSaundersland, OR 04634'},
#  {'nombre': 'Sandra Rodriguez',
#   'last_name': 'Mata',
#   'email': 'hthompson@example.net',
#   'address': '976 Tracie Isle Suite 375\nAvilachester, WY 51233'},
#  {'nombre': 'Michael Powers',
#   'last_name': 'Carpenter',
#   'email': 'gonzalezstephen@example.org',
#   'address': '8720 Robert Row Apt. 531\nSouth Rachelmouth, NJ 70708'},
#  {'nombre': 'Anthony Miller',
#   'last_name': 'Barron',
#   'email': 'kristy25@example.net',
#   'address': '745 Andrea Vista\nHoustonhaven, KS 25160'},
#  {'nombre': 'Katelyn Ramos',
#   'last_name': 'Davis',
#   'email': 'villegaserin@example.com',
#   'address': '71125 Schwartz Forges Suite 344\nWest Toniberg, CA 55519'},
#  {'nombre': 'Travis Suarez',
#   'last_name': 'Griffin',
#   'email': 'omartinez@example.net',
#   'address': '779 John Parkways Suite 503\nOliviahaven, AZ 82087'},
#  {'nombre': 'Denise Torres',
#   'last_name': 'Walker',
#   'email': 'ethan64@example.com',
#   'address': 'USS Gilbert\nFPO AP 33759'},
#  {'nombre': 'Emily Oconnor',
#   'last_name': 'Hines',
#   'email': 'aball@example.org',
#   'address': '3774 Castaneda Circle\nSouth Greghaven, NH 74262'},
#  {'nombre': 'Jordan Gonzalez',
#   'last_name': 'Wilson',
#   'email': 'sierra07@example.com',
#   'address': '725 Simmons Green\nSouth Ann, IL 20330'},
#  {'nombre': 'Kim Carroll',
#   'last_name': 'Wright',
#   'email': 'greenetina@example.org',
#   'address': 'Unit 0133 Box 4361\nDPO AE 17683'},
#  {'nombre': 'Hannah Gilbert',
#   'last_name': 'Duke',
#   'email': 'kellysummers@example.com',
#   'address': '85042 Antonio Plains Apt. 519\nGuerreroberg, KY 53081'},
#  {'nombre': 'Rebecca Banks',
#   'last_name': 'Riggs',
#   'email': 'stewartsara@example.org',
#   'address': '832 Moore Drives\nPort Laurenbury, OK 79672'},
#  {'nombre': 'Michael Harris',
#   'last_name': 'Johnston',
#   'email': 'ryanjessica@example.com',
#   'address': 'USCGC Faulkner\nFPO AA 82392'},
#  {'nombre': 'Crystal Webster',
#   'last_name': 'Shepherd',
#   'email': 'macdonaldmckenzie@example.org',
#   'address': '3590 Davis Ford\nLake Marcusland, PR 62177'},
#  {'nombre': 'Samuel Day',
#   'last_name': 'Russell',
#   'email': 'kellereric@example.net',
#   'address': '643 Shawn Club Apt. 354\nSouth Johnnyborough, LA 68133'},
#  {'nombre': 'Kyle Walker',
#   'last_name': 'Hooper',
#   'email': 'ericksontodd@example.org',
#   'address': '10032 Lopez Loop Suite 778\nLake Nicholasfort, NM 84752'},
#  {'nombre': 'Danielle Marshall',
#   'last_name': 'Taylor',
#   'email': 'cannonandrew@example.org',
#   'address': 'USCGC Austin\nFPO AE 53138'},
#  {'nombre': 'Anne Thomas',
#   'last_name': 'Fox',
#   'email': 'christopher60@example.org',
#   'address': '3560 Paul Curve\nSmithside, TX 46305'},
#  {'nombre': 'Tyler Robinson',
#   'last_name': 'Levine',
#   'email': 'jessica54@example.net',
#   'address': '819 Wilson Ford Apt. 942\nBillybury, NC 85092'},
#  {'nombre': 'Lisa Ayers',
#   'last_name': 'Murphy',
#   'email': 'dylancastillo@example.org',
#   'address': '50594 Kristin Motorway Suite 150\nEast Roytown, TN 72182'},
#  {'nombre': 'Anita Ramirez',
#   'last_name': 'Murphy',
#   'email': 'oliverangie@example.net',
#   'address': '53207 Samantha Shoal\nNorth Sarah, WA 44374'},
#  {'nombre': 'Marc Thompson',
#   'last_name': 'Mcdowell',
#   'email': 'pmejia@example.org',
#   'address': '3457 Wilson Well\nWest Lynn, IL 15264'},
#  {'nombre': 'Jacob Howard',
#   'last_name': 'Beltran',
#   'email': 'alexanderchristopher@example.com',
#   'address': '550 Ortiz Mountain\nMatthewport, IN 46368'},
#  {'nombre': 'Sylvia Potter',
#   'last_name': 'Morales',
#   'email': 'bethsmith@example.com',
#   'address': '1668 Castro Crossroad Suite 772\nKristenbury, AL 85780'},
#  {'nombre': 'Aaron Perkins',
#   'last_name': 'Patterson',
#   'email': 'jacksonsara@example.com',
#   'address': 'PSC 3095, Box 5918\nAPO AE 80181'},
#  {'nombre': 'Jesus Diaz',
#   'last_name': 'Hart',
#   'email': 'harrisstephen@example.net',
#   'address': '32524 Crane Causeway Apt. 659\nNorth Brianfort, VI 06334'},
#  {'nombre': 'Christopher Bridges',
#   'last_name': 'Lopez',
#   'email': 'emma88@example.net',
#   'address': 'Unit 4421 Box 3167\nDPO AE 23176'},
#  {'nombre': 'Breanna Odonnell',
#   'last_name': 'Powell',
#   'email': 'erika38@example.com',
#   'address': 'PSC 1294, Box 4250\nAPO AA 77154'},
#  {'nombre': 'Jennifer Schwartz',
#   'last_name': 'Anderson',
#   'email': 'jamescastillo@example.com',
#   'address': '359 Larsen Land Apt. 074\nJonbury, WY 66096'},
#  {'nombre': 'Dean Cooke',
#   'last_name': 'Stephens',
#   'email': 'garyhayden@example.org',
#   'address': '75282 Dean Neck Apt. 693\nEast Patriciaport, VI 48700'},
#  {'nombre': 'Mrs. Joanna Weaver MD',
#   'last_name': 'Robinson',
#   'email': 'joshua54@example.net',
#   'address': '2671 Walls Views Suite 704\nSouth Marissatown, CO 07289'},
#  {'nombre': 'Michael Harris',
#   'last_name': 'Morales',
#   'email': 'dhancock@example.com',
#   'address': '69071 Coleman Shoal Apt. 833\nPort Colin, VA 77080'},
#  {'nombre': 'Adriana Gomez',
#   'last_name': 'Mcpherson',
#   'email': 'daniel91@example.com',
#   'address': '44268 Mitchell Ville\nPort Kevinbury, IN 35593'},
#  {'nombre': 'Amy Martin',
#   'last_name': 'Wang',
#   'email': 'clintonwillis@example.net',
#   'address': '1525 Casey Harbors\nTerristad, AK 65408'},
#  {'nombre': 'Michael Colon',
#   'last_name': 'Johnson',
#   'email': 'taylor28@example.org',
#   'address': '06409 Graham Lights Apt. 785\nAcostaberg, TX 64653'},
#  {'nombre': 'Rachel Bonilla',
#   'last_name': 'Fisher',
#   'email': 'ikim@example.net',
#   'address': '8227 Dickson Throughway\nSalasburgh, WY 09028'},
#  {'nombre': 'Laurie Hawkins',
#   'last_name': 'Cortez',
#   'email': 'timothy62@example.org',
#   'address': '164 Laura Island\nSchultzchester, ND 76018'},
#  {'nombre': 'Sarah Hamilton',
#   'last_name': 'Johnson',
#   'email': 'john11@example.org',
#   'address': '9059 Horn Underpass\nLake Matthew, MP 31628'},
#  {'nombre': 'Melissa Arias',
#   'last_name': 'Ruiz',
#   'email': 'jadams@example.net',
#   'address': '49085 Michelle Burgs Suite 650\nLaneview, MS 14006'},
#  {'nombre': 'Mitchell Lee',
#   'last_name': 'Andrews',
#   'email': 'irusso@example.com',
#   'address': '430 Jeffery Corners\nCarriefort, VI 63768'},
#  {'nombre': 'Dorothy Downs',
#   'last_name': 'Stephenson',
#   'email': 'josebrown@example.com',
#   'address': '2278 Schaefer Neck Suite 028\nNew Chris, MP 74542'},
#  {'nombre': 'Bradley Villarreal',
#   'last_name': 'Burton',
#   'email': 'todd38@example.com',
#   'address': '784 Deborah Mill\nCherylmouth, WV 34476'},
#  {'nombre': 'Bryan Armstrong',
#   'last_name': 'Parrish',
#   'email': 'mitchellrobinson@example.org',
#   'address': '44139 Wilson Dale\nEspinozachester, AK 08497'},
#  {'nombre': 'Kyle Miller',
#   'last_name': 'Flowers',
#   'email': 'racosta@example.com',
#   'address': '67321 Mcdaniel Parkway\nWest Mark, RI 03458'},
#  {'nombre': 'Douglas Schaefer',
#   'last_name': 'Davis',
#   'email': 'ronald12@example.net',
#   'address': 'Unit 8153 Box 7847\nDPO AA 86160'},
#  {'nombre': 'Jeffrey Fisher',
#   'last_name': 'Beck',
#   'email': 'tadams@example.org',
#   'address': '5277 Barry Mission\nPhillipfurt, GA 60256'},
#  {'nombre': 'Donna Stuart',
#   'last_name': 'Brooks',
#   'email': 'todd03@example.com',
#   'address': '43707 Dixon Curve Apt. 845\nJoshuaburgh, ME 43273'},
#  {'nombre': 'Robert Gross',
#   'last_name': 'Sullivan',
#   'email': 'harveylaura@example.org',
#   'address': '6791 Shannon Mills Suite 258\nCheyenneview, FL 82562'},
#  {'nombre': 'Nicole Hudson',
#   'last_name': 'Mayo',
#   'email': 'andrea00@example.org',
#   'address': 'PSC 0530, Box 1283\nAPO AA 87141'},
#  {'nombre': 'Kelly Moore',
#   'last_name': 'Mccann',
#   'email': 'kathryn33@example.com',
#   'address': '066 Kimberly Stream\nGutierrezbury, MT 47281'},
#  {'nombre': 'James Watkins',
#   'last_name': 'Webb',
#   'email': 'valeriejohnson@example.com',
#   'address': '217 Nguyen Spring Apt. 501\nLake Kelly, OH 71032'},
#  {'nombre': 'Christine Morris',
#   'last_name': 'Moore',
#   'email': 'derekkey@example.org',
#   'address': '7513 Danny Underpass\nEast Tracie, NH 91312'},
#  {'nombre': 'Angie Richardson',
#   'last_name': 'Smith',
#   'email': 'mwelch@example.net',
#   'address': '6211 Dunlap Ferry Apt. 826\nAndrewbury, NJ 18323'},
#  {'nombre': 'Kelly James',
#   'last_name': 'Torres',
#   'email': 'zadams@example.org',
#   'address': 'Unit 7657 Box 0229\nDPO AA 27322'},
#  {'nombre': 'Amanda Merritt',
#   'last_name': 'Richardson',
#   'email': 'ugarcia@example.net',
#   'address': '1541 Wilson Square Apt. 759\nNew Michaeltown, IL 53991'},
#  {'nombre': 'Tabitha Gillespie',
#   'last_name': 'Edwards',
#   'email': 'justinsmith@example.net',
#   'address': '74602 Linda Hill Suite 445\nWatsonburgh, MI 98027'},
#  {'nombre': 'Brenda Rose',
#   'last_name': 'Sheppard',
#   'email': 'charlesjarvis@example.org',
#   'address': '0980 Aaron Island\nPhillipburgh, MO 78667'},
#  {'nombre': 'Gregory Murphy',
#   'last_name': 'Perry',
#   'email': 'dustinferguson@example.org',
#   'address': '92421 Leonard Lock Suite 453\nMistyside, VT 73259'},
#  {'nombre': 'Eric Warner',
#   'last_name': 'Travis',
#   'email': 'james48@example.com',
#   'address': '4547 Tony Fall Suite 301\nLake Mitchelltown, MA 58716'},
#  {'nombre': 'Summer Cabrera',
#   'last_name': 'Little',
#   'email': 'vbarton@example.net',
#   'address': '0815 Sara Mount Suite 069\nSimonmouth, VA 67700'},
#  {'nombre': 'Samantha Armstrong',
#   'last_name': 'Jones',
#   'email': 'kellyroman@example.com',
#   'address': '3543 Danielle Estates\nWest Jaimeborough, LA 83462'},
#  {'nombre': 'James Roth',
#   'last_name': 'Duarte',
#   'email': 'andrewtapia@example.org',
#   'address': '327 Diana Village\nCrossburgh, VT 80716'},
#  {'nombre': 'Robert Fitzgerald',
#   'last_name': 'Lambert',
#   'email': 'alejandrochurch@example.net',
#   'address': '648 David Heights Apt. 382\nTannerburgh, IA 30143'},
#  {'nombre': 'Richard Diaz',
#   'last_name': 'Anderson',
#   'email': 'alexisunderwood@example.com',
#   'address': '81000 Hodges Mission Suite 141\nDennisburgh, MN 91489'},
#  {'nombre': 'Kimberly Vance',
#   'last_name': 'Smith',
#   'email': 'ryan00@example.net',
#   'address': '561 Christopher Mills Apt. 078\nWest Anthony, NH 95971'},
#  {'nombre': 'Karen Baker',
#   'last_name': 'Soto',
#   'email': 'paul41@example.com',
#   'address': '5193 Mullins Trail Suite 207\nHaleyberg, AR 19890'},
#  {'nombre': 'Timothy Hurst',
#   'last_name': 'Morgan',
#   'email': 'kenneth14@example.com',
#   'address': '6241 Amy Squares Apt. 335\nAlisonmouth, NH 53998'},
#  {'nombre': 'Megan Davis',
#   'last_name': 'Malone',
#   'email': 'aroman@example.net',
#   'address': '431 Scott Ridge\nNorth Lisa, WY 92581'},
#  {'nombre': 'Erin Reed',
#   'last_name': 'Harvey',
#   'email': 'johnsdustin@example.com',
#   'address': 'USS Donaldson\nFPO AP 74682'},
#  {'nombre': 'Alexander Daniels',
#   'last_name': 'Anderson',
#   'email': 'andrewthomas@example.com',
#   'address': '3648 Ryan Unions Apt. 845\nAndrewchester, LA 00726'},
#  {'nombre': 'Andrew Young',
#   'last_name': 'Knight',
#   'email': 'diane75@example.net',
#   'address': '97758 Rodriguez Lodge\nPort Spencer, OR 15293'},
#  {'nombre': 'Kristen Phillips',
#   'last_name': 'Sherman',
#   'email': 'framirez@example.com',
#   'address': '708 Daniel Stream\nEast Alexanderstad, MH 61196'},
#  {'nombre': 'Tara Duke',
#   'last_name': 'Silva',
#   'email': 'rebeccawalsh@example.org',
#   'address': 'Unit 6104 Box 8056\nDPO AE 83838'},
#  {'nombre': 'Nicole Potter',
#   'last_name': 'Miller',
#   'email': 'ramirezgeorge@example.net',
#   'address': '422 David Stravenue Apt. 579\nDerrickborough, TX 40561'},
#  {'nombre': 'Tammy Bates',
#   'last_name': 'Marks',
#   'email': 'kthomas@example.net',
#   'address': '09535 Samantha Island\nStephaniemouth, NC 72192'},
#  {'nombre': 'Amy Olson',
#   'last_name': 'Ross',
#   'email': 'phillip55@example.net',
#   'address': '70130 Collins Island Apt. 526\nWest Kylemouth, DC 85691'},
#  {'nombre': 'Timothy Miller',
#   'last_name': 'Diaz',
#   'email': 'knappmichelle@example.com',
#   'address': '9694 Schmidt Cove Apt. 583\nNorth Katrinaberg, KS 92340'},
#  {'nombre': 'Kimberly Brown',
#   'last_name': 'Simmons',
#   'email': 'ghopkins@example.org',
#   'address': '0564 Daniel Heights Suite 701\nWilliambury, CT 55863'},
#  {'nombre': 'Tiffany Thomas',
#   'last_name': 'Mcguire',
#   'email': 'cody74@example.org',
#   'address': '0099 Joshua Junction Apt. 326\nBrittanyton, CA 15430'},
#  {'nombre': 'Michael Garcia',
#   'last_name': 'Oneal',
#   'email': 'cory37@example.org',
#   'address': '105 Joseph Ferry Apt. 032\nAndreaville, MN 71981'},
#  {'nombre': 'Mrs. Stacy Day',
#   'last_name': 'Williams',
#   'email': 'hendersonchristopher@example.net',
#   'address': '9482 Daisy Harbors\nSouth Morganshire, WY 00986'},
#  {'nombre': 'Billy Newman',
#   'last_name': 'Berry',
#   'email': 'victor90@example.net',
#   'address': '69152 Ponce Knolls Suite 343\nEast Elaine, IN 25473'},
#  {'nombre': 'Micheal Hopkins',
#   'last_name': 'Gutierrez',
#   'email': 'andrew11@example.com',
#   'address': '70681 Charles Loop Suite 942\nKleinborough, KY 24369'},
#  {'nombre': 'Erica Brown',
#   'last_name': 'Davis',
#   'email': 'smithdonald@example.net',
#   'address': '1418 Smith Estates\nNorth Markmouth, VA 89637'},
#  {'nombre': 'Blake Mcintosh',
#   'last_name': 'Smith',
#   'email': 'cbryant@example.org',
#   'address': '218 Sanchez Forest\nHernandezmouth, OK 21413'},
#  {'nombre': 'Melissa Chandler',
#   'last_name': 'Ross',
#   'email': 'russellandrew@example.com',
#   'address': '868 Bailey Mews Apt. 999\nSanchezland, AL 63512'},
#  ...]

# %%
data = pd.DataFrame(lista)

# %%
data
# Out:
#                 nombre last_name                       email  \
# 0     Nicholas Whitney  Peterson           jay10@example.net
# 1       Eric Gallagher   Alvarez       vgonzalez@example.org
# 2          Jeremy Ware     Brown  stanleycarroll@example.org
# 3           Omar Price      Knox       deborah17@example.com
# 4         Justin Patel    Powell          adam77@example.net
# ...                ...       ...                         ...
# 9995       Emily Chang     Moore      brookssean@example.com
# 9996   Vanessa Leonard    Bowman          pwhite@example.org
# 9997    Margaret Reyes    Dalton     gardnerdawn@example.net
# 9998      Brandi Brown      King   alexanderkoch@example.com
# 9999     Jessica Mejia    Hughes       ananelson@example.org
#
#                                                 address
# 0          3043 Nicole Spur\nNorth Angelaland, NC 88693
# 1           376 Jacqueline Coves\nNorth Sarah, NH 34867
# 2       5278 Simpson Forks\nNorth Thomasburgh, NY 48842
# 3     311 Montoya Mills Apt. 799\nSouth Jenna, DC 84325
# 4          48759 Edwards Pines\nLake Kimberly, MD 44577
# ...                                                 ...
# 9995    872 Petersen Squares\nNorth Stephanie, VT 14514
# 9996  9085 Olson Ports Suite 917\nWilliamsmouth, NM ...
# 9997  0524 Natalie Grove Apt. 884\nNorth Jenny, MT 9...
# 9998  72339 Taylor Hollow Suite 222\nJohnsonburgh, L...
# 9999          86142 Martin Camp\nKimberlyside, OR 79044
#
# [10000 rows x 4 columns]

# %%
import numpy as np

# %%
data['age'] = np.random.randint(30, 40, data.shape[0])

# %%
data
# Out:
#                 nombre last_name                       email  \
# 0     Nicholas Whitney  Peterson           jay10@example.net
# 1       Eric Gallagher   Alvarez       vgonzalez@example.org
# 2          Jeremy Ware     Brown  stanleycarroll@example.org
# 3           Omar Price      Knox       deborah17@example.com
# 4         Justin Patel    Powell          adam77@example.net
# ...                ...       ...                         ...
# 9995       Emily Chang     Moore      brookssean@example.com
# 9996   Vanessa Leonard    Bowman          pwhite@example.org
# 9997    Margaret Reyes    Dalton     gardnerdawn@example.net
# 9998      Brandi Brown      King   alexanderkoch@example.com
# 9999     Jessica Mejia    Hughes       ananelson@example.org
#
#                                                 address  age
# 0          3043 Nicole Spur\nNorth Angelaland, NC 88693   32
# 1           376 Jacqueline Coves\nNorth Sarah, NH 34867   35
# 2       5278 Simpson Forks\nNorth Thomasburgh, NY 48842   31
# 3     311 Montoya Mills Apt. 799\nSouth Jenna, DC 84325   34
# 4          48759 Edwards Pines\nLake Kimberly, MD 44577   37
# ...                                                 ...  ...
# 9995    872 Petersen Squares\nNorth Stephanie, VT 14514   32
# 9996  9085 Olson Ports Suite 917\nWilliamsmouth, NM ...   32
# 9997  0524 Natalie Grove Apt. 884\nNorth Jenny, MT 9...   38
# 9998  72339 Taylor Hollow Suite 222\nJohnsonburgh, L...   33
# 9999          86142 Martin Camp\nKimberlyside, OR 79044   32
#
# [10000 rows x 5 columns]

# %%
provincias = ["Loja", "Pichincha", "Guayas", "Azuay", "Manabí"]
data['provincia'] = np.random.choice(provincias, size=data.shape[0])

# %%
data
# Out:
#                 nombre last_name                       email  \
# 0     Nicholas Whitney  Peterson           jay10@example.net
# 1       Eric Gallagher   Alvarez       vgonzalez@example.org
# 2          Jeremy Ware     Brown  stanleycarroll@example.org
# 3           Omar Price      Knox       deborah17@example.com
# 4         Justin Patel    Powell          adam77@example.net
# ...                ...       ...                         ...
# 9995       Emily Chang     Moore      brookssean@example.com
# 9996   Vanessa Leonard    Bowman          pwhite@example.org
# 9997    Margaret Reyes    Dalton     gardnerdawn@example.net
# 9998      Brandi Brown      King   alexanderkoch@example.com
# 9999     Jessica Mejia    Hughes       ananelson@example.org
#
#                                                 address  age  provincia
# 0          3043 Nicole Spur\nNorth Angelaland, NC 88693   32  Pichincha
# 1           376 Jacqueline Coves\nNorth Sarah, NH 34867   35     Manabí
# 2       5278 Simpson Forks\nNorth Thomasburgh, NY 48842   31       Loja
# 3     311 Montoya Mills Apt. 799\nSouth Jenna, DC 84325   34       Loja
# 4          48759 Edwards Pines\nLake Kimberly, MD 44577   37     Guayas
# ...                                                 ...  ...        ...
# 9995    872 Petersen Squares\nNorth Stephanie, VT 14514   32       Loja
# 9996  9085 Olson Ports Suite 917\nWilliamsmouth, NM ...   32  Pichincha
# 9997  0524 Natalie Grove Apt. 884\nNorth Jenny, MT 9...   38  Pichincha
# 9998  72339 Taylor Hollow Suite 222\nJohnsonburgh, L...   33     Guayas
# 9999          86142 Martin Camp\nKimberlyside, OR 79044   32      Azuay
#
# [10000 rows x 6 columns]
